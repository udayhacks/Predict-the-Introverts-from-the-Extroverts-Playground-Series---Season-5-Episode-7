# %%
import pandas as pd

# %%
data = pd.read_csv("X:/july/personality_datasert.csv")

# %%
data
# Out:
#       Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0                  4.0         No                      4.0            6.0
# 1                  9.0        Yes                      0.0            0.0
# 2                  9.0        Yes                      1.0            2.0
# 3                  0.0         No                      6.0            7.0
# 4                  3.0         No                      9.0            4.0
# ...                ...        ...                      ...            ...
# 2895               3.0         No                      7.0            6.0
# 2896               3.0         No                      8.0            3.0
# 2897               4.0        Yes                      1.0            1.0
# 2898              11.0        Yes                      1.0            3.0
# 2899               3.0         No                      6.0            6.0
#
#      Drained_after_socializing  Friends_circle_size  Post_frequency  \
# 0                           No                 13.0             5.0
# 1                          Yes                  0.0             3.0
# 2                          Yes                  5.0             2.0
# 3                           No                 14.0             8.0
# 4                           No                  8.0             5.0
# ...                        ...                  ...             ...
# 2895                        No                  6.0             6.0
# 2896                        No                 14.0             9.0
# 2897                       Yes                  4.0             0.0
# 2898                       Yes                  2.0             0.0
# 2899                        No                  6.0             9.0
#
#      Personality
# 0      Extrovert
# 1      Introvert
# 2      Introvert
# 3      Extrovert
# 4      Extrovert
# ...          ...
# 2895   Extrovert
# 2896   Extrovert
# 2897   Introvert
# 2898   Introvert
# 2899   Extrovert
#
# [2900 rows x 8 columns]

# %%
data.shape
# Out:
# (2900, 8)

# %%
class Details:
    def __init__(self,data):
        self.data = data 
        
    def shape(self):
        return data.shape
    def total(self):
        return data.size
    def columns(self):
        k = list(data.columns)
        return k 
    
    def tell(self):
        print("Its shape is "+ str(self.total()))
        k = (list((self.shape())))
        print("Its Toatal elements are " ,end = "")
        print(k)

        print("Columns are :" ,self.columns())

# %%
a = Details(data)
a.total()
a.shape()
a.tell()
# Out:
# Its shape is 23200
# Its Toatal elements are [2900, 8]
# Columns are : ['Time_spent_Alone', 'Stage_fear', 'Social_event_attendance', 'Going_outside', 'Drained_after_socializing', 'Friends_circle_size', 'Post_frequency', 'Personality']

# %%
data.isnull().sum()
# Out:
# Time_spent_Alone             0
# Stage_fear                   0
# Social_event_attendance      0
# Going_outside                0
# Drained_after_socializing    0
# Friends_circle_size          0
# Post_frequency               0
# Personality                  0
# dtype: int64

# %%
data.describe()
# Out:
#        Time_spent_Alone  Social_event_attendance  Going_outside  \
# count       2900.000000              2900.000000    2900.000000
# mean           4.505816                 3.963354       3.000000
# std            3.441180                 2.872608       2.221597
# min            0.000000                 0.000000       0.000000
# 25%            2.000000                 2.000000       1.000000
# 50%            4.000000                 3.963354       3.000000
# 75%            7.000000                 6.000000       5.000000
# max           11.000000                10.000000       7.000000
#
#        Friends_circle_size  Post_frequency
# count          2900.000000     2900.000000
# mean              6.268863        3.564727
# std               4.232340        2.893587
# min               0.000000        0.000000
# 25%               3.000000        1.000000
# 50%               5.000000        3.000000
# 75%              10.000000        6.000000
# max              15.000000       10.000000

# %%
p = data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2900 entries, 0 to 2899
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Time_spent_Alone           2900 non-null   float64
#  1   Stage_fear                 2900 non-null   object
#  2   Social_event_attendance    2900 non-null   float64
#  3   Going_outside              2900 non-null   float64
#  4   Drained_after_socializing  2900 non-null   object
#  5   Friends_circle_size        2900 non-null   float64
#  6   Post_frequency             2900 non-null   float64
#  7   Personality                2900 non-null   object
# dtypes: float64(5), object(3)
# memory usage: 181.4+ KB

# %%
type(data.dtypes)
# Out:
# pandas.core.series.Series

# %%
objects = list(data.select_dtypes(include = object).columns)

# %%
type(objects)
# Out:
# list

# %%
objects

encoded = {
    "Yes":1,"No":0,
    "Extrovert":1,"Introvert":0 
           }

# %%
for i in  objects:
    if i != 'Personality':
        data[i] = data[i].map({"Yes":1,"No":0})
    else:
        data[i] = data[i].map({"Extrovert":1,"Introvert":0})

# %%
data
# Out:
#       Time_spent_Alone  Stage_fear  Social_event_attendance  Going_outside  \
# 0                  4.0           0                      4.0            6.0
# 1                  9.0           1                      0.0            0.0
# 2                  9.0           1                      1.0            2.0
# 3                  0.0           0                      6.0            7.0
# 4                  3.0           0                      9.0            4.0
# ...                ...         ...                      ...            ...
# 2895               3.0           0                      7.0            6.0
# 2896               3.0           0                      8.0            3.0
# 2897               4.0           1                      1.0            1.0
# 2898              11.0           1                      1.0            3.0
# 2899               3.0           0                      6.0            6.0
#
#       Drained_after_socializing  Friends_circle_size  Post_frequency  \
# 0                             0                 13.0             5.0
# 1                             1                  0.0             3.0
# 2                             1                  5.0             2.0
# 3                             0                 14.0             8.0
# 4                             0                  8.0             5.0
# ...                         ...                  ...             ...
# 2895                          0                  6.0             6.0
# 2896                          0                 14.0             9.0
# 2897                          1                  4.0             0.0
# 2898                          1                  2.0             0.0
# 2899                          0                  6.0             9.0
#
#       Personality
# 0               1
# 1               0
# 2               0
# 3               1
# 4               1
# ...           ...
# 2895            1
# 2896            1
# 2897            0
# 2898            0
# 2899            1
#
# [2900 rows x 8 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2900 entries, 0 to 2899
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Time_spent_Alone           2900 non-null   float64
#  1   Stage_fear                 2900 non-null   int64
#  2   Social_event_attendance    2900 non-null   float64
#  3   Going_outside              2900 non-null   float64
#  4   Drained_after_socializing  2900 non-null   int64
#  5   Friends_circle_size        2900 non-null   float64
#  6   Post_frequency             2900 non-null   float64
#  7   Personality                2900 non-null   int64
# dtypes: float64(5), int64(3)
# memory usage: 181.4 KB

# %%
#conversion of data 
for  i in data.columns:
    data[i]  = data[i].round().astype(int)

# %%
data
# Out:
#       Time_spent_Alone  Stage_fear  Social_event_attendance  Going_outside  \
# 0                    4           0                        4              6
# 1                    9           1                        0              0
# 2                    9           1                        1              2
# 3                    0           0                        6              7
# 4                    3           0                        9              4
# ...                ...         ...                      ...            ...
# 2895                 3           0                        7              6
# 2896                 3           0                        8              3
# 2897                 4           1                        1              1
# 2898                11           1                        1              3
# 2899                 3           0                        6              6
#
#       Drained_after_socializing  Friends_circle_size  Post_frequency  \
# 0                             0                   13               5
# 1                             1                    0               3
# 2                             1                    5               2
# 3                             0                   14               8
# 4                             0                    8               5
# ...                         ...                  ...             ...
# 2895                          0                    6               6
# 2896                          0                   14               9
# 2897                          1                    4               0
# 2898                          1                    2               0
# 2899                          0                    6               9
#
#       Personality
# 0               1
# 1               0
# 2               0
# 3               1
# 4               1
# ...           ...
# 2895            1
# 2896            1
# 2897            0
# 2898            0
# 2899            1
#
# [2900 rows x 8 columns]

# %%
# zero as converting into int 
import matplotlib.pyplot as plt

# %%
import seaborn as sb
import matplotlib.pyplot as plt

for col in data.columns[:-1]:
    plt.figure(figsize=(8, 4))
    sb.barplot(x=col, y=data.columns[-1], data=data)
    plt.title(f'{data.columns[-1]} by {col}')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
# !ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
train = pd.read_csv("train.csv")
train
# Out:
#           id  Time_spent_Alone Stage_fear  Social_event_attendance  \
# 0          0               0.0         No                      6.0
# 1          1               1.0         No                      7.0
# 2          2               6.0        Yes                      1.0
# 3          3               3.0         No                      7.0
# 4          4               1.0         No                      4.0
# ...      ...               ...        ...                      ...
# 18519  18519               3.0         No                      7.0
# 18520  18520               1.0        NaN                      6.0
# 18521  18521               7.0        Yes                      1.0
# 18522  18522               NaN        Yes                      1.0
# 18523  18523               1.0         No                      8.0
#
#        Going_outside Drained_after_socializing  Friends_circle_size  \
# 0                4.0                        No                 15.0
# 1                3.0                        No                 10.0
# 2                0.0                       NaN                  3.0
# 3                3.0                        No                 11.0
# 4                4.0                        No                 13.0
# ...              ...                       ...                  ...
# 18519            3.0                        No                  9.0
# 18520            7.0                        No                  6.0
# 18521            1.0                       Yes                  1.0
# 18522            0.0                       Yes                  5.0
# 18523            6.0                        No                  4.0
#
#        Post_frequency Personality
# 0                 5.0   Extrovert
# 1                 8.0   Extrovert
# 2                 0.0   Introvert
# 3                 5.0   Extrovert
# 4                 NaN   Extrovert
# ...               ...         ...
# 18519             7.0   Extrovert
# 18520             5.0   Extrovert
# 18521             NaN   Introvert
# 18522             2.0   Introvert
# 18523             7.0   Extrovert
#
# [18524 rows x 9 columns]

# %%
train_data = list(train.columns)
train_data
data_col = list(data.columns)
train_data == data_col
for i in train_data : 
    print(i)
# Out:
# id
# Time_spent_Alone
# Stage_fear
# Social_event_attendance
# Going_outside
# Drained_after_socializing
# Friends_circle_size
# Post_frequency
# Personality

# %%
for i in data_col:
    print(i)
# Out:
# Time_spent_Alone
# Stage_fear
# Social_event_attendance
# Going_outside
# Drained_after_socializing
# Friends_circle_size
# Post_frequency
# Personality

# %%
data["id"] =list(range(18525,18525+2900))

# %%
data
# Out:
#       Time_spent_Alone  Stage_fear  Social_event_attendance  Going_outside  \
# 0                    4           0                        4              6
# 1                    9           1                        0              0
# 2                    9           1                        1              2
# 3                    0           0                        6              7
# 4                    3           0                        9              4
# ...                ...         ...                      ...            ...
# 2895                 3           0                        7              6
# 2896                 3           0                        8              3
# 2897                 4           1                        1              1
# 2898                11           1                        1              3
# 2899                 3           0                        6              6
#
#       Drained_after_socializing  Friends_circle_size  Post_frequency  \
# 0                             0                   13               5
# 1                             1                    0               3
# 2                             1                    5               2
# 3                             0                   14               8
# 4                             0                    8               5
# ...                         ...                  ...             ...
# 2895                          0                    6               6
# 2896                          0                   14               9
# 2897                          1                    4               0
# 2898                          1                    2               0
# 2899                          0                    6               9
#
#       Personality     id
# 0               1  18525
# 1               0  18526
# 2               0  18527
# 3               1  18528
# 4               1  18529
# ...           ...    ...
# 2895            1  21420
# 2896            1  21421
# 2897            0  21422
# 2898            0  21423
# 2899            1  21424
#
# [2900 rows x 9 columns]

# %%
samp = pd.read_csv("sample_submission.csv")
samp
# Out:
#          id Personality
# 0     18524   Extrovert
# 1     18525   Extrovert
# 2     18526   Extrovert
# 3     18527   Extrovert
# 4     18528   Extrovert
# ...     ...         ...
# 6170  24694   Extrovert
# 6171  24695   Extrovert
# 6172  24696   Extrovert
# 6173  24697   Extrovert
# 6174  24698   Extrovert
#
# [6175 rows x 2 columns]

# %%
data["id"].value_counts().sum()
# Out:
# np.int64(2900)

# %% [markdown]
# # Acutal important data

# %% [markdown]
# # Test data

# %%
test = pd.read_csv("test.csv")

# %% [markdown]
# # Train data

# %%
train = pd.read_csv("train.csv")

# %% [markdown]
# # Handling the null values

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6175 entries, 0 to 6174
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         6175 non-null   int64
#  1   Time_spent_Alone           5750 non-null   float64
#  2   Stage_fear                 5577 non-null   object
#  3   Social_event_attendance    5778 non-null   float64
#  4   Going_outside              5709 non-null   float64
#  5   Drained_after_socializing  5743 non-null   object
#  6   Friends_circle_size        5825 non-null   float64
#  7   Post_frequency             5767 non-null   float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 386.1+ KB

# %%
nulls_train = {}

for col in train.columns:
    null_count = train[col].isnull().sum()
    dtype = train[col].dtype   # <- consistent with train
    nulls_train[col] = [int(null_count), dtype]

# %%
nulls_test = {}
for i in test.columns:
    nulls_test[i] = [int(test[i].isnull().sum()),test[i].dtype]

# %% [markdown]
# # Below are all null values from train and test data along with its dataype

# %%
nulls_test
# Out:
# {'id': [0, dtype('int64')],
#  'Time_spent_Alone': [425, dtype('float64')],
#  'Stage_fear': [598, dtype('O')],
#  'Social_event_attendance': [397, dtype('float64')],
#  'Going_outside': [466, dtype('float64')],
#  'Drained_after_socializing': [432, dtype('O')],
#  'Friends_circle_size': [350, dtype('float64')],
#  'Post_frequency': [408, dtype('float64')]}

# %%
nulls_train
# Out:
# {'id': [0, dtype('int64')],
#  'Time_spent_Alone': [1190, dtype('float64')],
#  'Stage_fear': [1893, dtype('O')],
#  'Social_event_attendance': [1180, dtype('float64')],
#  'Going_outside': [1466, dtype('float64')],
#  'Drained_after_socializing': [1149, dtype('O')],
#  'Friends_circle_size': [1054, dtype('float64')],
#  'Post_frequency': [1264, dtype('float64')],
#  'Personality': [0, dtype('O')]}

# %%
#nulls_test

# %% [markdown]
# # Using the Impute technique

# %%
from sklearn.impute import SimpleImputer
imputer_mean = SimpleImputer(strategy='mean')
imputer_mode = SimpleImputer(strategy='most_frequent')

# %%
train
# Out:
#           id  Time_spent_Alone Stage_fear  Social_event_attendance  \
# 0          0               0.0         No                      6.0
# 1          1               1.0         No                      7.0
# 2          2               6.0        Yes                      1.0
# 3          3               3.0         No                      7.0
# 4          4               1.0         No                      4.0
# ...      ...               ...        ...                      ...
# 18519  18519               3.0         No                      7.0
# 18520  18520               1.0        NaN                      6.0
# 18521  18521               7.0        Yes                      1.0
# 18522  18522               NaN        Yes                      1.0
# 18523  18523               1.0         No                      8.0
#
#        Going_outside Drained_after_socializing  Friends_circle_size  \
# 0                4.0                        No                 15.0
# 1                3.0                        No                 10.0
# 2                0.0                       NaN                  3.0
# 3                3.0                        No                 11.0
# 4                4.0                        No                 13.0
# ...              ...                       ...                  ...
# 18519            3.0                        No                  9.0
# 18520            7.0                        No                  6.0
# 18521            1.0                       Yes                  1.0
# 18522            0.0                       Yes                  5.0
# 18523            6.0                        No                  4.0
#
#        Post_frequency Personality
# 0                 5.0   Extrovert
# 1                 8.0   Extrovert
# 2                 0.0   Introvert
# 3                 5.0   Extrovert
# 4                 NaN   Extrovert
# ...               ...         ...
# 18519             7.0   Extrovert
# 18520             5.0   Extrovert
# 18521             NaN   Introvert
# 18522             2.0   Introvert
# 18523             7.0   Extrovert
#
# [18524 rows x 9 columns]

# %%
train_numerical_cols = train.select_dtypes(include=['int64', 'float64']).columns
train_categorical_cols = train.select_dtypes(include=['object']).columns
test_numerical_cols = test.select_dtypes(include=['int64', 'float64']).columns
test_categorical_cols = test.select_dtypes(include=['object']).columns

# %%
for i in train_numerical_cols:
    train[i] = imputer_mean.fit_transform(train[[i]])
   
for i in train_categorical_cols:
    train[i] = imputer_mode.fit_transform(train[[i]]).ravel()

# %%
for i in test_numerical_cols:
    test[i] = imputer_mean.fit_transform(test[[i]])
for i in test_categorical_cols:
    test[i] = imputer_mode.fit_transform(test[[i]]).ravel()

# %%
train.isnull().sum()
# Out:
# id                           0
# Time_spent_Alone             0
# Stage_fear                   0
# Social_event_attendance      0
# Going_outside                0
# Drained_after_socializing    0
# Friends_circle_size          0
# Post_frequency               0
# Personality                  0
# dtype: int64

# %%
train.describe()
# Out:
#                  id  Time_spent_Alone  Social_event_attendance  Going_outside  \
# count  18524.000000      18524.000000             18524.000000   18524.000000
# mean    9261.500000          3.137764                 5.265106       4.044319
# std     5347.562529          2.905696                 2.664215       1.979276
# min        0.000000          0.000000                 0.000000       0.000000
# 25%     4630.750000          1.000000                 3.000000       3.000000
# 50%     9261.500000          3.000000                 5.265106       4.000000
# 75%    13892.250000          4.000000                 7.000000       6.000000
# max    18523.000000         11.000000                10.000000       7.000000
#
#        Friends_circle_size  Post_frequency
# count         18524.000000    18524.000000
# mean              7.996737        4.982097
# std               4.101561        2.779168
# min               0.000000        0.000000
# 25%               5.000000        3.000000
# 50%               8.000000        5.000000
# 75%              11.000000        7.000000
# max              15.000000       10.000000

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18524 entries, 0 to 18523
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         18524 non-null  float64
#  1   Time_spent_Alone           18524 non-null  float64
#  2   Stage_fear                 18524 non-null  object
#  3   Social_event_attendance    18524 non-null  float64
#  4   Going_outside              18524 non-null  float64
#  5   Drained_after_socializing  18524 non-null  object
#  6   Friends_circle_size        18524 non-null  float64
#  7   Post_frequency             18524 non-null  float64
#  8   Personality                18524 non-null  object
# dtypes: float64(6), object(3)
# memory usage: 1.3+ MB

# %%
train
# Out:
#             id  Time_spent_Alone Stage_fear  Social_event_attendance  \
# 0          0.0          0.000000         No                      6.0
# 1          1.0          1.000000         No                      7.0
# 2          2.0          6.000000        Yes                      1.0
# 3          3.0          3.000000         No                      7.0
# 4          4.0          1.000000         No                      4.0
# ...        ...               ...        ...                      ...
# 18519  18519.0          3.000000         No                      7.0
# 18520  18520.0          1.000000         No                      6.0
# 18521  18521.0          7.000000        Yes                      1.0
# 18522  18522.0          3.137764        Yes                      1.0
# 18523  18523.0          1.000000         No                      8.0
#
#        Going_outside Drained_after_socializing  Friends_circle_size  \
# 0                4.0                        No                 15.0
# 1                3.0                        No                 10.0
# 2                0.0                        No                  3.0
# 3                3.0                        No                 11.0
# 4                4.0                        No                 13.0
# ...              ...                       ...                  ...
# 18519            3.0                        No                  9.0
# 18520            7.0                        No                  6.0
# 18521            1.0                       Yes                  1.0
# 18522            0.0                       Yes                  5.0
# 18523            6.0                        No                  4.0
#
#        Post_frequency Personality
# 0            5.000000   Extrovert
# 1            8.000000   Extrovert
# 2            0.000000   Introvert
# 3            5.000000   Extrovert
# 4            4.982097   Extrovert
# ...               ...         ...
# 18519        7.000000   Extrovert
# 18520        5.000000   Extrovert
# 18521        4.982097   Introvert
# 18522        2.000000   Introvert
# 18523        7.000000   Extrovert
#
# [18524 rows x 9 columns]

# %%
test
# Out:
#            id  Time_spent_Alone Stage_fear  Social_event_attendance  \
# 0     18524.0           3.00000         No                      7.0
# 1     18525.0           3.11687        Yes                      0.0
# 2     18526.0           3.00000         No                      5.0
# 3     18527.0           3.00000         No                      4.0
# 4     18528.0           9.00000        Yes                      1.0
# ...       ...               ...        ...                      ...
# 6170  24694.0           3.00000         No                      5.0
# 6171  24695.0           8.00000        Yes                      2.0
# 6172  24696.0           2.00000         No                      4.0
# 6173  24697.0           3.00000         No                      4.0
# 6174  24698.0           3.11687        Yes                      1.0
#
#       Going_outside Drained_after_socializing  Friends_circle_size  \
# 0               4.0                        No                  6.0
# 1               0.0                       Yes                  5.0
# 2               6.0                        No                 15.0
# 3               4.0                        No                  5.0
# 4               2.0                       Yes                  1.0
# ...             ...                       ...                  ...
# 6170            5.0                        No                  9.0
# 6171            1.0                       Yes                  0.0
# 6172            3.0                        No                  9.0
# 6173            4.0                        No                 11.0
# 6174            1.0                       Yes                  1.0
#
#       Post_frequency
# 0           5.028958
# 1           1.000000
# 2           9.000000
# 3           6.000000
# 4           1.000000
# ...              ...
# 6170        6.000000
# 6171        0.000000
# 6172        7.000000
# 6173        9.000000
# 6174        0.000000
#
# [6175 rows x 8 columns]

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6175 entries, 0 to 6174
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         6175 non-null   float64
#  1   Time_spent_Alone           6175 non-null   float64
#  2   Stage_fear                 6175 non-null   object
#  3   Social_event_attendance    6175 non-null   float64
#  4   Going_outside              6175 non-null   float64
#  5   Drained_after_socializing  6175 non-null   object
#  6   Friends_circle_size        6175 non-null   float64
#  7   Post_frequency             6175 non-null   float64
# dtypes: float64(6), object(2)
# memory usage: 386.1+ KB

# %% [markdown]
# # Encode

# %%
n = len(test_categorical_cols)
print("Number of categorical columns in test data:", n)
for i in test_categorical_cols:
    print(i, "-->", test[i].unique())

print("////////////////////////////////////////////////////")


n = len(train_categorical_cols)
print("Number of categorical columns in train data:", n)
for i in train_categorical_cols:
    print(i, "-->", train[i].unique())
# Out:
# Number of categorical columns in test data: 2
# Stage_fear --> ['No' 'Yes']
# Drained_after_socializing --> ['No' 'Yes']
# ////////////////////////////////////////////////////
# Number of categorical columns in train data: 3
# Stage_fear --> ['No' 'Yes']
# Drained_after_socializing --> ['No' 'Yes']
# Personality --> ['Extrovert' 'Introvert']

# %%
categorical_vals = {
    "Yes":1,"No":0,
    "Extrovert":1,"Introvert":0 
           }

# %%
for i in train_categorical_cols:
    if i != 'Personality':
        train[i] = train[i].map({"Yes":1,"No":0})
    else:
        train[i] = train[i].map({"Extrovert":1,"Introvert":0})
        
for i in test_categorical_cols:
    test[i] = test[i].map({"Yes":1,"No":0})

# %%
test
# Out:
#            id  Time_spent_Alone  Stage_fear  Social_event_attendance  \
# 0     18524.0           3.00000           0                      7.0
# 1     18525.0           3.11687           1                      0.0
# 2     18526.0           3.00000           0                      5.0
# 3     18527.0           3.00000           0                      4.0
# 4     18528.0           9.00000           1                      1.0
# ...       ...               ...         ...                      ...
# 6170  24694.0           3.00000           0                      5.0
# 6171  24695.0           8.00000           1                      2.0
# 6172  24696.0           2.00000           0                      4.0
# 6173  24697.0           3.00000           0                      4.0
# 6174  24698.0           3.11687           1                      1.0
#
#       Going_outside  Drained_after_socializing  Friends_circle_size  \
# 0               4.0                          0                  6.0
# 1               0.0                          1                  5.0
# 2               6.0                          0                 15.0
# 3               4.0                          0                  5.0
# 4               2.0                          1                  1.0
# ...             ...                        ...                  ...
# 6170            5.0                          0                  9.0
# 6171            1.0                          1                  0.0
# 6172            3.0                          0                  9.0
# 6173            4.0                          0                 11.0
# 6174            1.0                          1                  1.0
#
#       Post_frequency
# 0           5.028958
# 1           1.000000
# 2           9.000000
# 3           6.000000
# 4           1.000000
# ...              ...
# 6170        6.000000
# 6171        0.000000
# 6172        7.000000
# 6173        9.000000
# 6174        0.000000
#
# [6175 rows x 8 columns]

# %%
train = train.round().astype(int)

# %%
data = data.round().astype(int)

# %%
total_train = pd.concat([train, data], ignore_index=True)

# %%
total_train
# Out:
#           id  Time_spent_Alone  Stage_fear  Social_event_attendance  \
# 0          0                 0           0                        6
# 1          1                 1           0                        7
# 2          2                 6           1                        1
# 3          3                 3           0                        7
# 4          4                 1           0                        4
# ...      ...               ...         ...                      ...
# 21419  21420                 3           0                        7
# 21420  21421                 3           0                        8
# 21421  21422                 4           1                        1
# 21422  21423                11           1                        1
# 21423  21424                 3           0                        6
#
#        Going_outside  Drained_after_socializing  Friends_circle_size  \
# 0                  4                          0                   15
# 1                  3                          0                   10
# 2                  0                          0                    3
# 3                  3                          0                   11
# 4                  4                          0                   13
# ...              ...                        ...                  ...
# 21419              6                          0                    6
# 21420              3                          0                   14
# 21421              1                          1                    4
# 21422              3                          1                    2
# 21423              6                          0                    6
#
#        Post_frequency  Personality
# 0                   5            1
# 1                   8            1
# 2                   0            0
# 3                   5            1
# 4                   5            1
# ...               ...          ...
# 21419               6            1
# 21420               9            1
# 21421               0            0
# 21422               0            0
# 21423               9            1
#
# [21424 rows x 9 columns]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV, StratifiedKFold

# %%
param_grid = [
    # lbfgs – supports only l2
    {
        'penalty': ['l2'],
        'solver': ['lbfgs'],
        'multi_class': ['ovr', 'multinomial'],
        'C': [0.01, 0.1, 1, 10],
        'class_weight': [None, 'balanced'],
        'max_iter': [100, 500],
        'tol': [1e-4],
        'fit_intercept': [True, False],
        'warm_start': [False],
    },
    # saga – supports l1 and l2
    {
        'penalty': ['l1', 'l2'],
        'solver': ['saga'],
        'multi_class': ['ovr', 'multinomial'],
        'C': [0.01, 0.1, 1, 10],
        'class_weight': [None, 'balanced'],
        'max_iter': [100, 500],
        'tol': [1e-4],
        'fit_intercept': [True, False],
        'warm_start': [False],
    },
    # saga – elasticnet
    {
        'penalty': ['elasticnet'],
        'solver': ['saga'],
        'multi_class': ['ovr', 'multinomial'],
        'C': [0.01, 0.1, 1, 10],
        'class_weight': [None, 'balanced'],
        'max_iter': [100, 500],
        'tol': [1e-4],
        'fit_intercept': [True, False],
        'l1_ratio': [0.0, 0.5, 1.0],
        'warm_start': [False],
    }
]

# %%
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
grid_search = GridSearchCV(
    estimator=LogisticRegression(),
    param_grid=param_grid,
    cv=cv,
    scoring='accuracy',           # You can also try 'f1', 'roc_auc', etc.
    verbose=1,
    n_jobs=-1                     # Use all CPU cores
)

# %%
from sklearn.model_selection import train_test_split
X = total_train.drop("Personality", axis=1)  # Features
y = total_train["Personality"]               # Target

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,            # 20% test, 80% train
    random_state=42,          # For reproducibility
    stratify=y                # Maintain class distribution
)

# %%
"""X = total_train.drop(columns=['Personality'])
y = total_train['Personality']"""
# Out:
# "X = total_train.drop(columns=['Personality'])\ny = total_train['Personality']"

# %%
grid_search.fit(X, y)
# Out:
# Fitting 5 folds for each of 384 candidates, totalling 1920 fits
# C:\Users\freak\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\linear_model\_logistic.py:1273: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. Use OneVsRestClassifier(LogisticRegression(..)) instead. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\freak\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\linear_model\_logistic.py:470: ConvergenceWarning: lbfgs failed to converge after 500 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=500).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=LogisticRegression(), n_jobs=-1,
#              param_grid=[{'C': [0.01, 0.1, 1, 10],
#                           'class_weight': [None, 'balanced'],
#                           'fit_intercept': [True, False],
#                           'max_iter': [100, 500],
#                           'multi_class': ['ovr', 'multinomial'],
#                           'penalty': ['l2'], 'solver': ['lbfgs'],
#                           'tol': [0.0001], 'warm_start': [False]},
#                          {'C': [0.01,...
#                           'penalty': ['l1', 'l2'], 'solver': ['saga'],
#                           'tol': [0.0001], 'warm_start': [False]},
#                          {'C': [0.01, 0.1, 1, 10],
#                           'class_weight': [None, 'balanced'],
#                           'fit_intercept': [True, False],
#                           'l1_ratio': [0.0, 0.5, 1.0], 'max_iter': [100, 500],
#                           'multi_class': ['ovr', 'multinomial'],
#                           'penalty': ['elasticnet'], 'solver': ['saga'],
#                           'tol': [0.0001], 'warm_start': [False]}],
#              scoring='accuracy', verbose=1)

# %%
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

from sklearn.metrics import classification_report,confusion_matrix, ConfusionMatrixDisplay
print(classification_report(y_test, y_pred))  # if you have true test labels
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.93      0.93      1247
#            1       0.97      0.97      0.97      3038
#
#     accuracy                           0.96      4285
#    macro avg       0.95      0.95      0.95      4285
# weighted avg       0.96      0.96      0.96      4285

# %%
ConfusionMatrixDisplay.from_estimator(best_model, X_test, y_test, cmap='Blues')
plt.title("Confusion Matrix")
plt.show()
